# %% [markdown]
# #my notebook

# %%
5+5
# Out:
# 10

# %%
import random


for i in range(6):
  x = random.randint(2,7)
  print(x)
# Out:
# 6
# 5
# 4
# 5
# 2
# 2

# %%
import numpy as  np
import pandas as pd
from time import sleep

x=[1,2,3]
x = pd.linspace
sleep(2)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,20,200)
plt.plot(x,np.cos(x))
plt.show()
